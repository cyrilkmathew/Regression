# %% [markdown]
# # Polynomial Regression
#
# ##### https://www.javatpoint.com/machine-learning-polynomial-regression

# %% [markdown]
# ### Import the  libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Import the  dataset

# %%
dataset = pd.read_csv("Position_Salaries.csv")
X = dataset.iloc[:,1:-1].values
y = dataset.iloc[:,-1].values

# %% [markdown]
# ### Train the linear regression model on the whole data

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X,y)
# Out:
# LinearRegression()

# %% [markdown]
# ### Train the polynomial regression model on the whole data

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 4) # parameter of n
X_poly = poly_reg.fit_transform(X) # 
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly,y)
# Out:
# LinearRegression()

# %% [markdown]
# ### Visualising the linear regression result

# %%
plt.scatter(X,y, color = 'red')
plt.plot(X,lin_reg.predict(X), color = 'blue')
plt.title('Trute or bluff (LR)')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ### Visualising the polynomial regression result

# %%
plt.scatter(X,y, color = 'red')
plt.plot(X,lin_reg_2.predict(X_poly), color = 'blue')
plt.title('Trute or bluff (LR)')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ### Visualising the polynomial regression result (for higher resolution and smoother cure)

# %%
X_grid = np.arange(min(X),max(X),0.1)
X_grid = X_grid.reshape((len(X_grid),1))
plt.scatter(X,y, color = 'red')
plt.plot(X,lin_reg_2.predict(X_poly), color = 'blue')
plt.title('Trute or bluff (LR)')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ### Predicting a new reult with linear regression

# %%
lin_reg.predict([[6.5]])
# Out:
# array([330378.78787879])

# %% [markdown]
# ### Predicting a new reult with polynomial regression

# %%
# In the case of polynomial predection need a fit_transform the data 

lin_reg_2.predict(poly_reg.fit_transform([[6.5]]))
# Out:
# array([158862.45265155])
